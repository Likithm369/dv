# %%
#1GA24CS403 NETFLIX DATA ANALYSIS

# %%
# Pie chart: Distribution of content categories
category_counts = df['Category'].value_counts()
plt.figure()
plt.pie(category_counts, labels=category_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Content Category Distribution', fontsize=16, fontweight='bold')
plt.tight_layout()
plt.savefig('pie_chart.png')
plt.show()

# %%
import matplotlib.pyplot as plt

top_countries = df['Country'].value_counts().head(10)
colors = ['#FF6F61', '#6B5B95', '#88B04B', '#F7CAC9', '#92A8D1',
          '#955251', '#B565A7', '#009B77', '#DD4124', '#45B8AC']

top_countries.plot(kind='barh', color=colors)
plt.title("Top 10 Content-Producing Countries")
plt.xlabel("Number of Titles")
plt.ylabel("Country")
plt.show()

# %%
year_counts = df['release_year'].value_counts().sort_index()
year_counts.plot(kind='bar', color='red')
plt.title("Content Released Per Year")
plt.xlabel("Year")
plt.ylabel("Count")
plt.show()

# %%
peak_movie_year = yearly['Movie'].idxmax()
print(f"Peak year for Movie releases: {peak_movie_year}")
# Out:
# Peak year for Movie releases: 2019.0

# %%
peak_tv_show_year = yearly['TV Show'].idxmax()
print(f"Peak year for TV Show releases: {peak_tv_show_year}")
# Out:
# Peak year for TV Show releases: 2020.0

# %%
rating_counts = df['Rating'].value_counts().head(6)
plt.pie(rating_counts, labels=rating_counts.index, autopct='%1.1f%%', startangle=90)
plt.title("Top Ratings Distribution")
plt.show()

# %%
    #Top Genres for Movies
    df_movies_genre = df_genre[df_genre['Category'] == 'Movie']
    top_movie_genres = count_genres(df_movies_genre['Type']).head(10)
    plt.figure()
    sns.barplot(x='Count', y='Genre', data=top_movie_genres, palette='plasma', hue='Genre', legend=False)
    plt.title('Top 10 Movie Genres', fontsize=16, fontweight='bold')
    plt.xlabel('Number of Movies', fontsize=12)
    plt.ylabel('Genre', fontsize=12)
    plt.tight_layout()
    plt.savefig('7_top_movie_genres.png')
    plt.show()

# %%
plt.scatter(df_movies['release_year'], df_movies['duration_min'], color='tomato', alpha=0.6)
plt.title('Release Year vs Duration (Movies)')
plt.xlabel('Year')
plt.ylabel('Duration (min)')
plt.show()

# %%
year_counts = df['release_year'].value_counts().sort_index()
plt.plot(year_counts.index, year_counts.values, marker='o', color='green')
plt.title('Titles Added Over Years')
plt.xlabel('Year')
plt.ylabel('Number of Titles')
plt.grid(True, ls='--', lw=0.5)
plt.show()

# %%
countries = df['Country'].value_counts().head(5)
plt.pie(countries, labels=countries.index, autopct='%1.1f%%', startangle=90,
        colors=['#ffb6b9','#fae3d9','#bbded6','#8ac6d1','#6c5b7b'],
        wedgeprops={'width':0.4})
plt.title('Top 5 Content-Producing Countries')
plt.show()

# %%
df_movies = df[df['Category'] == 'Movie'].copy()
df_movies['duration_min'] = df_movies['Duration'].str.extract(r'(\d+)').astype(float)
plt.hist(df_movies['duration_min'].dropna(), bins=20, color='orange', edgecolor='black')
plt.title('Movie Duration Distribution')
plt.xlabel('Duration (min)')
plt.ylabel('Count')
plt.show()

# %%
#DONE
